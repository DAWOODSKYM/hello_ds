# %%
import pandas as pd
import numpy as np
data = pd.read_csv("C:/Users/user/Desktop/hello_ds/titanic3.csv")

# %% [markdown]
# #### To remove empty cells

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %% [markdown]
# #### Visualize some of the coloumns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='survived', ylabel='fare'>

# %% [markdown]
# ##### These graphs are helpful in seeing some of the relationships between survival and the input variables of the data, but it's also possible to use pandas to calculate correlations. To do so, all the variables used need to be numeric for the correlation calculation and currently gender is stored as a string. To convert those string values to integers, add and run the following code.

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %% [markdown]
# ##### Now, you can analyze the correlation between all the input variables to identify the features that would be the best inputs to a machine learning model. The closer a value is to 1, the higher the correlation between the value and the result. Use the following code to correlate the relationship between all variables and survival.

# %%
data.corr().abs()[["survived"]]

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sibsp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\user\Desktop\hello_ds\hello.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/hello_ds/hello.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/hello_ds/hello.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> data.corr().abs()[["survived"]]
#
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:831, in FrameApply.apply(self)
#     828 elif self.raw:
#     829     return self.apply_raw()
# --> 831 return self.apply_standard()
#
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:957, in FrameApply.apply_standard(self)
#     956 def apply_standard(self):
# --> 957     results, res_index = self.apply_series_generator()
#     959     # wrap results
#     960     return self.wrap_results(results, res_index)
#
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\apply.py:973, in FrameApply.apply_series_generator(self)
#     970 with option_context("mode.chained_assignment", None):
#     971     for i, v in enumerate(series_gen):
#     972         # ignore SettingWithCopy here in case the user mutates
# --> 973         results[i] = self.func(v, *self.args, **self.kwargs)
#     974         if isinstance(results[i], ABCSeries):
#     975             # If we have a view on v, we need to make a copy because
#     976             #  series_generator will swap out the underlying data
#     977             results[i] = results[i].copy(deep=False)
#
# c:\Users\user\Desktop\hello_ds\hello.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/hello_ds/hello.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/hello_ds/hello.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> data.corr().abs()[["survived"]]
#
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File c:\Users\user\miniconda3\envs\myenv\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'sibsp'

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %% [markdown]
# ## Train and Evaluate the Model
#
# #### Start with splitting the data into training and validation data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %% [markdown]
# ##### normalize the inputs such that all features are treated equally. For example, within the dataset the values for age range from ~0-100, while gender is only a 1 or 0. By normalizing all the variables, you can ensure that the ranges of values are all the same. Use the following code in a new code cell to scale the input values.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %% [markdown]
# ##### There are many different machine learning algorithms that you could choose from to model the data. The scikit-learn library also provides support for many of them and a chart to help select the one that's right for your scenario. For now, use the Naïve Bayes algorithm, a common algorithm for classification problems. Add a cell with the following code to create and train the algorithm.

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ##### Test the trained Model using the test data

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %% [markdown]
# ### Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %% [markdown]
# ### Add layers of the neural network

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
#  dense_3 (Dense)             (None, 5)                 10
#
#  dense_4 (Dense)             (None, 5)                 30
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 112 (448.00 Byte)
# Trainable params: 112 (448.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### Once the model is created, it needs to be compiled. As part of this, you need to define what type of optimizer will be used, how loss will be calculated, and what metric should be optimized for. Add the following code to build and train the model.

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 2ms/step - loss: 0.6926 - accuracy: 0.5526
# Epoch 2/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6877 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.5861
# Epoch 6/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6852 - accuracy: 0.5861
# Epoch 7/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6840 - accuracy: 0.5861
# Epoch 8/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6830 - accuracy: 0.5861
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.5861
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6808 - accuracy: 0.5861
# Epoch 11/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.5861
# Epoch 12/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.5861
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6764 - accuracy: 0.5861
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6737 - accuracy: 0.5861
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6699 - accuracy: 0.5861
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6648 - accuracy: 0.5861
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6596 - accuracy: 0.5861
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6530 - accuracy: 0.5861
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6455 - accuracy: 0.5861
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6371 - accuracy: 0.5861
# Epoch 21/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6277 - accuracy: 0.5861
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6195 - accuracy: 0.5861
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6103 - accuracy: 0.5861
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6014 - accuracy: 0.5861
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5929 - accuracy: 0.5861
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5851 - accuracy: 0.5861
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5777 - accuracy: 0.5861
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5704 - accuracy: 0.5861
# Epoch 29/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5640 - accuracy: 0.6495
# Epoch 30/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5589 - accuracy: 0.7859
# Epoch 31/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5554 - accuracy: 0.7871
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5528 - accuracy: 0.7919
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5496 - accuracy: 0.7943
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5474 - accuracy: 0.7931
# Epoch 35/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7943
# Epoch 36/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5427 - accuracy: 0.7955
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7919
# Epoch 38/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5393 - accuracy: 0.7907
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5378 - accuracy: 0.7907
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5357 - accuracy: 0.7907
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.7895
# Epoch 42/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5323 - accuracy: 0.7895
# Epoch 43/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5310 - accuracy: 0.7883
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5293 - accuracy: 0.7907
# Epoch 45/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5279 - accuracy: 0.7871
# Epoch 46/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5276 - accuracy: 0.7919
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5262 - accuracy: 0.7907
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5241 - accuracy: 0.7895
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7883
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5219 - accuracy: 0.7907

# %% [markdown]
# #### Test the trained model on the test data

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 1ms/step
# 0.8038277511961722
